# %% [markdown]
# # MY PYTHON CODING CLASS
# #### project title
# ####### ![5d092a36-f0c0-4a88-84e4-604d037ebbf6.jpeg](attachment:5d092a36-f0c0-4a88-84e4-604d037ebbf6.jpeg)This is introduction to jupyter notebook
#
# # MY POINTS IN ORDER
# 1. how to use code
# 2. image inserting  learning
# 3. use of keys  learning
# 4. code/variables learning

# %% [markdown]
# ## about to write my first python code
# print('hello world, im writting python programme language')

# %% [markdown]
# # VARIABLE AND IDENTIFIER
# - in python, variable is an entity/object located on tthe computer memory
# - identifier is used to identify variables
#
# ##RULES FOR NAMING VARIABLES
# 1. variable should be descriptive
# 2. variable name can not start with a number,though number can be found anywhere else
# 3. any special characther except underscore can not be used in naming varables
# 4. space can not be used to join words in naming variable,use under_score instead

# %%
first_name="EMMA"
last_name="UCHE"
age=100
print("my name is",first_name ,last_name,"i am", age, "years old)")
# Out:
# my name is EMMA UCHE i am 100 years old)

# %%
first_name= input("please enter your first name")
last_name= input()  
age = input("pease enter your age")
print("my name is",first_name, last_name ,"and i am", age, "years old")
# Out:
# please enter your first nameEMMA
# UCHE
# pease enter your age100
# my name is EMMA UCHE and i am 100 years old

# %% [markdown]
# # OPERATOR IN PYTHON
# operator is used to manipulate oprand
#
# ##types of operators
# 1. arithematic operator
# 2. assignment operator
# 3. comparisson operator
# 4. identity operator
# 5. membership operator
# 6. logical operator
# 7. btwise operator.

# %% [markdown]
# # ARITHEMATIC

# %%
# addition(+)
a= 12
b= 10
c= a+b
print(c)
# Out:
# 22

# %%
# subtraction(-)
a= 12
b= 10
c= a-b
print(c)
# Out:
# 2

# %%
# multiplication(*)
a= 12
b= 10
c= a*b
print(c)
# Out:
# 120

# %%
# power(**)
a= 16
b= 2
c= a**b
print(c)
# Out:
# 256

# %% [markdown]
# # ASSIGNMENT OPERATOR

# %%
# equal to(=)
name ="EMMA"
print (name)
# Out:
# EMMA

# %%
# increament(+=)
a= 10
a+=5 #increase the value of a by 5
print (a)
# Out:
# 15

# %%
# decreament(-=)
a =10
a-=3 # decrease the value of a by three
print (a)
# Out:
# 7

# %% [markdown]
# # COMPARISON OPERATOR
#  is used to compare variales,and it return boolen results

# %%
# equal equal to (==)
a = 4
b = 7
a== b #check if a is the same as b
# Out:
# False

# %%
# equal equal to (==)
a = 4
b = 4
a== b #check if a is the same as b
# Out:
# True

# %%
# greater than (>)
a = 4
b = 7
a== b #check if a is greater than b
# Out:
# False

# %%
# greater than or equal to (>=)
a =7 
b =7 
a== b #check if a is greater than or qual to b
# Out:
# True

# %%
# lesser than or equal to(<=)
a = 4
b = 7
a <= b # check if a lesser than b
# Out:
# True

# %% [markdown]
# # IDENTITY OPERATOR
#
# to check if two variables are of the same memory locations, and to return borlan results.
# is/ is not

# %%
a = 2
b = 2
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %% [markdown]
# # MEMBERSHIP OPERATOR
# in / not in

# %%
a = (2, 5, 7, 9)# list
2 in a  #check if 2 is a member as list a
# Out:
# True

# %% [markdown]
# #
